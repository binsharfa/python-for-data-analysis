# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
data = [1, 1.2, "string", True]
s = pd.Series(data)

# %%
s
# Out:
# 0         1
# 1       1.2
# 2    string
# 3      True
# dtype: object

# %%
s1 = pd.Series([1.2, 3.4, 5.6, 7.8, 13.5])
s1
# Out:
# 0     1.2
# 1     3.4
# 2     5.6
# 3     7.8
# 4    13.5
# dtype: float64

# %%
pd.Series?

# %%
data = np.random.normal(5, 2.5, size=26)
letters = list("abcdefghijklmnopqrstuvwxyz")

s2 = pd.Series(data, index=letters, name="example", dtype=np.float16)
s2
# Out:
# a     5.281250
# b     5.878906
# c     8.382812
# d     1.741211
# e     4.519531
# f     8.976562
# g     7.488281
# h     6.320312
# i    10.328125
# j     3.279297
# k    -2.246094
# l     5.300781
# m     1.142578
# n     5.753906
# o     8.945312
# p     6.519531
# q     5.453125
# r     2.876953
# s     5.914062
# t     6.746094
# u     6.027344
# v     4.117188
# w     5.566406
# x     6.898438
# y     6.257812
# z     5.394531
# Name: example, dtype: float16

# %%
s2['v']
# Out:
# 4.117

# %%
s2['c':'n']
# Out:
# c     8.382812
# d     1.741211
# e     4.519531
# f     8.976562
# g     7.488281
# h     6.320312
# i    10.328125
# j     3.279297
# k    -2.246094
# l     5.300781
# m     1.142578
# n     5.753906
# Name: example, dtype: float16

# %%
s2 < 0
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# k     True
# l    False
# m    False
# n    False
# o    False
# p    False
# q    False
# r    False
# s    False
# t    False
# u    False
# v    False
# w    False
# x    False
# y    False
# z    False
# Name: example, dtype: bool

# %%
s2[s2 < 0]
# Out:
# k   -2.246094
# Name: example, dtype: float16

# %%
s3 = np.exp(s2)
s3
# Out:
# a      196.625000
# b      357.500000
# c     4372.000000
# d        5.703125
# e       91.812500
# f     7916.000000
# g     1787.000000
# h      555.500000
# i    30576.000000
# j       26.562500
# k        0.105835
# l      200.500000
# m        3.134766
# n      315.500000
# o     7672.000000
# p      678.500000
# q      233.500000
# r       17.765625
# s      370.250000
# t      850.500000
# u      414.500000
# v       61.375000
# w      261.500000
# x      990.500000
# y      522.000000
# z      220.250000
# Name: example, dtype: float16

# %%
'a' in s2
# Out:
# True

# %%
'A' in s2
# Out:
# False

# %%
s3['x']
# Out:
# 990.5

# %%
s3 == 990.5
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# k    False
# l    False
# m    False
# n    False
# o    False
# p    False
# q    False
# r    False
# s    False
# t    False
# u    False
# v    False
# w    False
# x     True
# y    False
# z    False
# Name: example, dtype: bool

# %%
s3[s3 == 990.5]
# Out:
# x    990.5
# Name: example, dtype: float16

# %% [markdown]
# ## DataFrame

# %%
data = {
    "state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Virginia", "Virginia"],
    "year": [2000, 2001, 2002, 2000, 2001, 2001, 2002],
    "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2, 4.5]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       state  year  pop
# 0      Ohio  2000  1.5
# 1      Ohio  2001  1.7
# 2      Ohio  2002  3.6
# 3    Nevada  2000  2.4
# 4    Nevada  2001  2.9
# 5  Virginia  2001  3.2
# 6  Virginia  2002  4.5

# %%
df.head(n=10)
# Out:
#       state  year  pop
# 0      Ohio  2000  1.5
# 1      Ohio  2001  1.7
# 2      Ohio  2002  3.6
# 3    Nevada  2000  2.4
# 4    Nevada  2001  2.9
# 5  Virginia  2001  3.2
# 6  Virginia  2002  4.5

# %%
df.tail()
# Out:
#       state  year  pop
# 2      Ohio  2002  3.6
# 3    Nevada  2000  2.4
# 4    Nevada  2001  2.9
# 5  Virginia  2001  3.2
# 6  Virginia  2002  4.5

# %%
df.tail(n=3)
# Out:
#       state  year  pop
# 4    Nevada  2001  2.9
# 5  Virginia  2001  3.2
# 6  Virginia  2002  4.5

# %%
df["pop"]
# Out:
# 0    1.5
# 1    1.7
# 2    3.6
# 3    2.4
# 4    2.9
# 5    3.2
# 6    4.5
# Name: pop, dtype: float64

# %%
df.loc[1, "state"]
# Out:
# 'Ohio'

# %%
df.loc[1:6, ["state", "pop"]]
# Out:
#       state  pop
# 1      Ohio  1.7
# 2      Ohio  3.6
# 3    Nevada  2.4
# 4    Nevada  2.9
# 5  Virginia  3.2
# 6  Virginia  4.5

# %%
df["state"] == "Ohio"
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# Name: state, dtype: bool

# %%
df.loc[df["state"] == "Ohio"]
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
df.loc[df["pop"] < 3]
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 3  Nevada  2000  2.4
# 4  Nevada  2001  2.9

# %%
df
# Out:
#       state  year  pop
# 0      Ohio  2000  1.5
# 1      Ohio  2001  1.7
# 2      Ohio  2002  3.6
# 3    Nevada  2000  2.4
# 4    Nevada  2001  2.9
# 5  Virginia  2001  3.2
# 6  Virginia  2002  4.5

# %%
df["debt"] = pd.NA

# %%
df
# Out:
#       state  year  pop  debt
# 0      Ohio  2000  1.5  <NA>
# 1      Ohio  2001  1.7  <NA>
# 2      Ohio  2002  3.6  <NA>
# 3    Nevada  2000  2.4  <NA>
# 4    Nevada  2001  2.9  <NA>
# 5  Virginia  2001  3.2  <NA>
# 6  Virginia  2002  4.5  <NA>

# %%
df["debt"] = [.34, 6.5, 568.56, 4235.5, 32.5, 6.7, 7.0]

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %% [markdown]
# ## Index Objects

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df2 = df.set_index(["state", "year"])

# %%
df2
# Out:
#                pop     debt
# state    year
# Ohio     2000  1.5     0.34
#          2001  1.7     6.50
#          2002  3.6   568.56
# Nevada   2000  2.4  4235.50
#          2001  2.9    32.50
# Virginia 2001  3.2     6.70
#          2002  4.5     7.00

# %%
df2.loc["Ohio"]
# Out:
#       pop    debt
# year
# 2000  1.5    0.34
# 2001  1.7    6.50
# 2002  3.6  568.56

# %%
df2.loc[("Ohio", 2001)]
# Out:
# pop     1.7
# debt    6.5
# Name: (Ohio, 2001), dtype: float64

# %%
df2.loc[:, "pop"]
# Out:
# state     year
# Ohio      2000    1.5
#           2001    1.7
#           2002    3.6
# Nevada    2000    2.4
#           2001    2.9
# Virginia  2001    3.2
#           2002    4.5
# Name: pop, dtype: float64

# %%
df2.loc[:, ["pop"]]
# Out:
#                pop
# state    year
# Ohio     2000  1.5
#          2001  1.7
#          2002  3.6
# Nevada   2000  2.4
#          2001  2.9
# Virginia 2001  3.2
#          2002  4.5

# %% [markdown]
# ## Essential functionality

# %%
s4 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
s4
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
new_index = np.arange(6)
s4.reindex(new_index, method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
s4.reindex?

# %%
s4.reindex(new_index, method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
s4.reindex(new_index, method="bfill")
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df.drop(2)
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df.drop([3,4,6])
# Out:
#       state  year  pop    debt
# 0      Ohio  2000  1.5    0.34
# 1      Ohio  2001  1.7    6.50
# 2      Ohio  2002  3.6  568.56
# 5  Virginia  2001  3.2    6.70

# %%
df.drop("state", axis=1)
# Out:
#    year  pop     debt
# 0  2000  1.5     0.34
# 1  2001  1.7     6.50
# 2  2002  3.6   568.56
# 3  2000  2.4  4235.50
# 4  2001  2.9    32.50
# 5  2001  3.2     6.70
# 6  2002  4.5     7.00

# %%
df.drop(["state", "pop"], axis=1)
# Out:
#    year     debt
# 0  2000     0.34
# 1  2001     6.50
# 2  2002   568.56
# 3  2000  4235.50
# 4  2001    32.50
# 5  2001     6.70
# 6  2002     7.00

# %%
s5 = pd.Series([1, 2, 3, 4], index=['a', 'c', 'd', 'e'])
s6 = pd.Series([10, 20, 30, 40, 50], index=['a', 'c', 'e', 'f', 'g'])

# %%
s5 + s6
# Out:
# a    11.0
# c    22.0
# d     NaN
# e    34.0
# f     NaN
# g     NaN
# dtype: float64

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df.describe() # very important!
# Out:
#               year       pop         debt
# count     7.000000  7.000000     7.000000
# mean   2001.000000  2.828571   693.871429
# std       0.816497  1.060997  1575.526913
# min    2000.000000  1.500000     0.340000
# 25%    2000.500000  2.050000     6.600000
# 50%    2001.000000  2.900000     7.000000
# 75%    2001.500000  3.400000   300.530000
# max    2002.000000  4.500000  4235.500000

# %%
df.set_index(["state", "year"]).describe()
# Out:
#             pop         debt
# count  7.000000     7.000000
# mean   2.828571   693.871429
# std    1.060997  1575.526913
# min    1.500000     0.340000
# 25%    2.050000     6.600000
# 50%    2.900000     7.000000
# 75%    3.400000   300.530000
# max    4.500000  4235.500000

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df.loc[:, ["state", "pop"]].groupby(["state"]).describe()
# Out:
#            pop
#          count      mean       std  min    25%   50%    75%  max
# state
# Nevada     2.0  2.650000  0.353553  2.4  2.525  2.65  2.775  2.9
# Ohio       3.0  2.266667  1.159023  1.5  1.600  1.70  2.650  3.6
# Virginia   2.0  3.850000  0.919239  3.2  3.525  3.85  4.175  4.5

# %%
df
# Out:
#       state  year  pop     debt
# 0      Ohio  2000  1.5     0.34
# 1      Ohio  2001  1.7     6.50
# 2      Ohio  2002  3.6   568.56
# 3    Nevada  2000  2.4  4235.50
# 4    Nevada  2001  2.9    32.50
# 5  Virginia  2001  3.2     6.70
# 6  Virginia  2002  4.5     7.00

# %%
df1 = df.set_index(["state", "year"])

# %%
df1
# Out:
#                pop     debt
# state    year
# Ohio     2000  1.5     0.34
#          2001  1.7     6.50
#          2002  3.6   568.56
# Nevada   2000  2.4  4235.50
#          2001  2.9    32.50
# Virginia 2001  3.2     6.70
#          2002  4.5     7.00

# %%
df1.loc["Nevada", :]
# Out:
#       pop    debt
# year
# 2000  2.4  4235.5
# 2001  2.9    32.5
